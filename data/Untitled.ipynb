# %%
import pandas as pd

# %%
df=pd.read_csv("shoes.csv")

# %%
df=df.head(100)

# %%
df[df['name'].str.contains("Sanda", case=False, na=False)]
# Out:
#    category       subcategory  \
# 11    shoes  Sandales & Mules
# 20    shoes  Sandales & Mules
# 25    shoes  Sandales & Mules
# 34    shoes          Sandales
# 36    shoes  Sandales & Mules
# 37    shoes  Sandales & Mules
# 38    shoes  Sandales & Mules
# 40    shoes  Sandales & Mules
# 41    shoes  Sandales & Mules
# 43    shoes  Sandales & Mules
# 47    shoes  Sandales & Mules
# 54    shoes          Sandales
# 55    shoes  Sandales & Mules
# 56    shoes          Sandales
# 57    shoes  Sandales & Mules
# 58    shoes  Sandales & Mules
# 70    shoes  Sandales & Mules
# 79    shoes  Sandales & Mules
# 84    shoes  Sandales & Mules
# 93    shoes          Sandales
# 95    shoes  Sandales & Mules
# 96    shoes  Sandales & Mules
# 97    shoes  Sandales & Mules
# 99    shoes  Sandales & Mules
#
#                                                  name  current_price  \
# 11                Sandales compensées à boucle évidée          30.67
# ...

# %%
category = "Sandales & Mules"
price = 60
df[(df['subcategory'] == category) & (df['current_price'] <= price)]
# Out:
#    category       subcategory                                      name  \
# 1     shoes  Sandales & Mules       Sandales compensées à boucle évidée
# 5     shoes  Sandales & Mules     SOCOFY sandales rétro creuses en cuir
# 6     shoes  Sandales & Mules    Sandales à bride arrière en forme de T
# 7     shoes  Sandales & Mules         Sandales élastiques Bande Comfort
# 8     shoes  Sandales & Mules  Sandales décontractées brodées de fleurs
# 14    shoes  Sandales & Mules       Sandales compensées à boucle évidée
# 18    shoes  Sandales & Mules     SOCOFY sandales rétro creuses en cuir
# 19    shoes  Sandales & Mules    Sandales à bride arrière en forme de T
# 20    shoes  Sandales & Mules         Sandales élastiques Bande Comfort
# 21    shoes  Sandales & Mules  Sandales décontractées brodées de fleurs
#
#     current_price  raw_price currency  discount  likes_count  is_new    brand  \
# 1           30.67      74.20      USD        59         7784   False  Lostisy
# ...

# %%
df.subcategory.unique()
# Out:
# array(['Mocassins', 'Sneakers & Baskets', 'Bottes & Bottines', 'Baskets',
#        'Sandales & Mules', 'Derbies & Mocassins',
#        'Bottes & Chaussures montantes', 'Sandales', 'Chaussons'],
#       dtype=object)

# %%
color = "Beige"
subcategory = "Sandales & Mules"
        
        # Filter the products by color and subcategory
filtered_products = df[((df['variation_0_color'] == color) | (df['variation_1_color'] == color)) & (df['subcategory'] == subcategory)]

# %%
filtered_products
# Out:
#    category       subcategory  \
# 40    shoes  Sandales & Mules
# 41    shoes  Sandales & Mules
# 55    shoes  Sandales & Mules
# 99    shoes  Sandales & Mules
#
#                                                  name  current_price  \
# 40           Sandales décontractées brodées de fleurs          22.61
# 41     SOCOFY sandales bohémiennes ajustables en cuir          70.25
# 55  SOCOFY Sandales Entredoigt Plates Fabriquées À...          25.96
# 99           Sandales décontractées brodées de fleurs          22.61
#
#     raw_price currency  discount  likes_count  is_new    brand  ...  \
# 40      54.30      USD        58          339   False  Lostisy  ...
# 41     133.64      USD        47         4439   False   Socofy  ...
# 55      52.69      USD        51         6653   False      NaN  ...
# 99      54.30      USD        58          339   False  Lostisy  ...
#
#    variation_0_color variation_1_color  \
# 40             Beige               Red
# ...

# %%
df.isnull().sum()
# Out:
# category                 0
# subcategory              0
# name                     0
# current_price            0
# raw_price                0
# currency                 0
# discount                 0
# likes_count              0
# is_new                   0
# brand                    0
# brand_url                0
# codCountry               0
# variation_0_color        0
# variation_1_color        0
# variation_0_thumbnail    0
# variation_0_image        0
# variation_1_thumbnail    0
# variation_1_image        0
# image_url                0
# url                      0
# id                       0
# model                    0
# dtype: int64

# %%
df=df.dropna()

# %%
df.to_csv('shoes.csv', index=False)

# %%
filtered_products
# Out:
# Empty DataFrame
# Columns: [category, subcategory, name, current_price, raw_price, currency, discount, likes_count, is_new, brand, brand_url, codCountry, variation_0_color, variation_1_color, variation_0_thumbnail, variation_0_image, variation_1_thumbnail, variation_1_image, image_url, url, id, model]
# Index: []
#
# [0 rows x 22 columns]

# %%
for p in df:
    print(p)
# Out:
# category
# subcategory
# name
# current_price
# raw_price
# currency
# discount
# likes_count
# is_new
# brand
# brand_url
# codCountry
# variation_0_color
# variation_1_color
# variation_0_thumbnail
# variation_0_image
# variation_1_thumbnail
# variation_1_image
# image_url
# url
# id
# model

# %%
if products_below_price:
    response = "Here are some products below ${}:\n".format(price)
    for product in products_below_price:
        response += "- {} (${:.2f})\n".format(product["name"], product["current_price"])
else:
    response = "No products found below ${}.".format(price)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 products_below_price = [p for p in df if p["current_price"] <= price]
#       3 if products_below_price:
#       4     response = "Here are some products below ${}:\n".format(price)
#
# Cell In[13], line 1, in <listcomp>(.0)
# ----> 1 products_below_price = [p for p in df if p["current_price"] <= price]
#       3 if products_below_price:
#       4     response = "Here are some products below ${}:\n".format(price)
#
# TypeError: string indices must be integers, not 'str'
